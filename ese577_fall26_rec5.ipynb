# %% [markdown]
# # Logistic regression
#
#
# ## 1) Linear separators
# Consider the training data set plotted below:
#
# <img src="https://drive.google.com/uc?export=view&id=1_fqE04I0neqMJAjWyCsMD45YxlHz43YN" width="500"/>
#
# Assume that $x^{(1)},\ldots, x^{(n)}$ are the coordinate vectors for the $n=9$ points shown on the figure, $y^{(1)}, \ldots, y^{(n)}$ are the corresponding labels (for example, $y^{(i)} = 1$ for the "$+$" points, $y^{(i)}=-1$ for the "$-$" points), and $h:\mathbb{R}^2 \mapsto \{+1, -1\}$ is a hypothesis for mapping the data point coordinates to the binary labels.

# %% [markdown]
# ### a)
# Find the classification accuracy of the hypothesis: $$h\left(\begin{bmatrix}x_1 \\ x_2\end{bmatrix}\right) = \begin{cases}+1 \quad \text{if } x_1+x_2 - 7>0\\ -1 \quad \text{if } x1 + x_2 - 7 \leq 0 \enspace,\end{cases}$$ on this training set. Accuracy is just the percentage of correctly classified examples.

# %% [markdown]
# ### b)
# Is it possible to achieve 100% accuracy with a linear hypothesis?

# %% [markdown]
# ### c)
# What is the highest possible classification accuracy? Draw a hyperplane (in 2D, a hyperplane is just a line) which defines a linear classifier that obtains the highest classification accuracy (or lowest 0-1 error). Be sure to also draw the normal vector. Specify values for $\theta, \theta_0$ that define the hyerplane you drew.

# %% [markdown]
# ### d) For practice, we can try a different hypothesis. Consider the hypothesis in the figure below.
# <img src="https://drive.google.com/uc?export=view&id=1r9A6aX-5HXvmRXh1dgAYBVhmPtCQUHYp" width="500"/>
#
# Find the parameters $\theta$ and $\theta_0$.

# %% [markdown]
# ### e)
# Suppose that we remove the datapoint $(3, 3)$ from our dataset. Let two hypotheses be considered different if there exists a test point (i.e., not necesarily from the dataset shown) that they would classify differently. How many different hypotheses are there that obtain zero training error?

# %% [markdown]
# ### d)
# In the set of solutions with zero training error, is there a reason to prefer any specific hypotheses over others? How might we find one or more of those?

# %% [markdown]
# ## 2) Linear separability
#
# For each of the following, determine if the statement is true or false.

# %% [markdown]
# ### a)
# If we take any linearly separable dataset and add a new feature, it is still guaranteed to be linearly separable.

# %% [markdown]
# ### b)
# If we take any linearly separable dataset and remove a feature, it is still guaranteed to be linearly separable.

# %% [markdown]
# ### c)
# If we take any dataset that is not linearly separable and remove a feature, it is still guaranteed to not be linearly separable.

# %% [markdown]
# ### d)
# If we take any dataset that is not linearly separable and remove a data point, it is still guaranteed to not be linearly separable.
